# %%
import pandas as pd
import seaborn as sb
import matplotlib.pylab as plt
# %reload_ext autoreload
# %autoreload 2

df = pd.read_csv('./zillowData/State_time_series.csv')

# %%
print(df.columns)

# %%
dfTest = df[['Date', 'Sale_Prices', 'RegionName']]
dfTest = dfTest.dropna(axis=0)
print(dfTest)

# %% [markdown]
# # Graphed price per month with color or year/ Never used

# %%
years = []
months = []
salePrice = []

dfSalePrice = df[['Date','Sale_Prices']]
dfSalePrice = dfSalePrice.dropna(axis=0)

for i in dfSalePrice['Sale_Prices']:
    salePrice.append(i)
    
for i in dfSalePrice['Date']:
    years.append(i[:-6])

for i in dfSalePrice['Date']:
    months.append(i[-5:-3])

marTotal = 0
marAverageSalePrice = []

aprTotal = 0
aprAverageSalePrice = []

mayTotal = 0
mayAverageSalePrice = []

junTotal = 0
junAverageSalePrice = []

julTotal = 0
julAverageSalePrice = []

augTotal = 0
augAverageSalePrice = []

sepTotal = 0
sepAverageSalePrice = []

octTotal = 0
octAverageSalePrice = []

novTotal = 0
novAverageSalePrice = []

decTotal = 0
decAverageSalePrice = []

marNum = 0
aprNum = 0
mayNum = 0
junNum = 0
julNum = 0
augNum = 0
sepNum = 0
octNum = 0
novNum = 0
decNum = 0

xlab = [years[1]]

yearToCheck = int(years[0])
print((yearToCheck))

for i in range(len(salePrice)):
    year = int(years[i])
    month = int(months[i])

    if (year == yearToCheck):
        
        if (month == 3):
            marTotal = marTotal + salePrice[i]
            marNum += 1
            
        if (month == 4):
            aprTotal = aprTotal + salePrice[i]
            aprNum += 1
            
        if (month == 5):
            mayTotal = mayTotal + salePrice[i]
            mayNum += 1
        
        if (month == 6):
            junTotal = junTotal + salePrice[i]
            junNum += 1
            
        if (month == 7):
            julTotal = julTotal + salePrice[i]
            julNum += 1
            
        if (month == 8):
            augTotal = augTotal + salePrice[i]
            augNum += 1
            
        if (month == 9):
            sepTotal = sepTotal + salePrice[i]
            sepNum += 1
            
        if (month == 10):
            octTotal = octTotal + salePrice[i]
            octNum += 1
            
        if (month == 11):
            novTotal = novTotal + salePrice[i]
            novNum += 1
            
        if (month == 12):
            decTotal = decTotal + salePrice[i]
            decNum += 1
        
    else:
        marAverageSalePrice.append(marTotal/marNum)
        aprAverageSalePrice.append(aprTotal/aprNum)
        mayAverageSalePrice.append(mayTotal/mayNum)
        junAverageSalePrice.append(junTotal/junNum)
        julAverageSalePrice.append(julTotal/julNum)
        augAverageSalePrice.append(augTotal/augNum)
        sepAverageSalePrice.append(sepTotal/sepNum)
        octAverageSalePrice.append(octTotal/octNum)
        novAverageSalePrice.append(novTotal/novNum)
        decAverageSalePrice.append(decTotal/decNum)
        yearToCheck += 1
        xlab.append(str(yearToCheck))
        total = 0
        num = 0
        
marAverageSalePrice.append(marTotal/marNum)
aprAverageSalePrice.append(aprTotal/aprNum)
mayAverageSalePrice.append(mayTotal/mayNum)
junAverageSalePrice.append(junTotal/junNum)
julAverageSalePrice.append(julTotal/julNum)
augAverageSalePrice.append(augTotal/augNum)
sepAverageSalePrice.append(sepTotal/sepNum)
octAverageSalePrice.append(octTotal/octNum)
novAverageSalePrice.append(novTotal/novNum)
decAverageSalePrice.append(decTotal/decNum)
  
print(marAverageSalePrice)
print(xlab)
print(len(mayAverageSalePrice))

plt.title("Average Sale Price per Year")
plt.xlabel("Year")
plt.ylabel("Price $")
sb.lineplot(x = xlab,y = marAverageSalePrice)
sb.lineplot(aprAverageSalePrice)
sb.lineplot(mayAverageSalePrice)
sb.lineplot(junAverageSalePrice)
sb.lineplot(julAverageSalePrice)
sb.lineplot(augAverageSalePrice)
sb.lineplot(sepAverageSalePrice)
sb.lineplot(octAverageSalePrice)
sb.lineplot(novAverageSalePrice)

# %% [markdown]
# # Average sale pr

# %%
years = []
prices = []
months = []

dfAvgPrice = df[[ 'Date','Sale_Prices']]
dfAvgPrice = dfAvgPrice.dropna(axis=0)
#print(df1)
janTotal = 0
febTotal = 0
marTotal = 0
aprTotal = 0
mayTotal = 0
junTotal = 0
julTotal = 0
augTotal = 0
sepTotal = 0
octTotal = 0
novTotal = 0
decTotal = 0

janNum = 0
febNum = 0
marNum = 0
aprNum = 0
mayNum = 0
junNum = 0
julNum = 0
augNum = 0
sepNum = 0
octNum = 0
novNum = 0
decNum = 0

for i in dfAvgPrice['Sale_Prices']:
    prices.append(i)
    
for i in dfAvgPrice['Date']:
    years.append(i[:-6])
    
for i in dfAvgPrice['Date']:
    months.append(i[-5:-3])
    
print(len(prices), len(months))

averagePrice = []
yearToCheck = int(years[0])
xlab = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

for i in range(len(prices)):
    month = int(months[i])
    
    if (month == 1):
        janTotal = janTotal + prices[i]
        janNum += 1
        
    if (month == 2):
        febTotal = febTotal + prices[i]
        febNum += 1
        
    if (month == 3):
        marTotal = marTotal + prices[i]
        marNum += 1
            
    if (month == 4):
        aprTotal = aprTotal + prices[i]
        aprNum += 1
            
    if (month == 5):
        mayTotal = mayTotal + prices[i]
        mayNum += 1
    
    if (month == 6):
        junTotal = junTotal + prices[i]
        junNum += 1
            
    if (month == 7):
        julTotal = julTotal + prices[i]
        julNum += 1
            
    if (month == 8):
        augTotal = augTotal + prices[i]
        augNum += 1
            
    if (month == 9):
        sepTotal = sepTotal + prices[i]
        sepNum += 1
            
    if (month == 10):
        octTotal = octTotal + prices[i]
        octNum += 1
            
    if (month == 11):
        novTotal = novTotal + prices[i]
        novNum += 1
            
    if (month == 12):
        decTotal = decTotal + prices[i]
        decNum += 1

averagePrice.append(janTotal/janNum)
averagePrice.append(febTotal/febNum)
averagePrice.append(marTotal/marNum)
averagePrice.append(aprTotal/aprNum)
averagePrice.append(mayTotal/mayNum)
averagePrice.append(junTotal/junNum)
averagePrice.append(julTotal/julNum)
averagePrice.append(augTotal/augNum)
averagePrice.append(sepTotal/sepNum)
averagePrice.append(octTotal/octNum)
averagePrice.append(novTotal/novNum)
averagePrice.append(decTotal/decNum)

print(min(averagePrice), max(averagePrice))


plt.figure()
plt.ylim(185000, 230000)
plt.title("Average sale prices nation wide per month")
plt.xlabel("Month")
plt.ylabel("Prices $")
plt.bar(xlab,averagePrice)

# %%
years = []
prices = []
months = []

dfMedPrice = df[[ 'Date','MedianListingPrice_AllHomes']]
dfMedPrice = dfMedPrice.dropna(axis=0)
#print(df1)
janTotal = 0
febTotal = 0
marTotal = 0
aprTotal = 0
mayTotal = 0
junTotal = 0
julTotal = 0
augTotal = 0
sepTotal = 0
octTotal = 0
novTotal = 0
decTotal = 0

janNum = 0
febNum = 0
marNum = 0
aprNum = 0
mayNum = 0
junNum = 0
julNum = 0
augNum = 0
sepNum = 0
octNum = 0
novNum = 0
decNum = 0

for i in dfMedPrice['MedianListingPrice_AllHomes']:
    prices.append(i)
    
for i in dfMedPrice['Date']:
    years.append(i[:-6])
    
for i in dfMedPrice['Date']:
    months.append(i[-5:-3])
    
print(len(prices), len(months))

averagePrice = []
yearToCheck = int(years[0])
xlab = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

for i in range(len(prices)):
    month = int(months[i])
    
    if (month == 1):
        janTotal = janTotal + prices[i]
        janNum += 1
        
    if (month == 2):
        febTotal = febTotal + prices[i]
        febNum += 1
        
    if (month == 3):
        marTotal = marTotal + prices[i]
        marNum += 1
            
    if (month == 4):
        aprTotal = aprTotal + prices[i]
        aprNum += 1
            
    if (month == 5):
        mayTotal = mayTotal + prices[i]
        mayNum += 1
    
    if (month == 6):
        junTotal = junTotal + prices[i]
        junNum += 1
            
    if (month == 7):
        julTotal = julTotal + prices[i]
        julNum += 1
            
    if (month == 8):
        augTotal = augTotal + prices[i]
        augNum += 1
            
    if (month == 9):
        sepTotal = sepTotal + prices[i]
        sepNum += 1
            
    if (month == 10):
        octTotal = octTotal + prices[i]
        octNum += 1
            
    if (month == 11):
        novTotal = novTotal + prices[i]
        novNum += 1
            
    if (month == 12):
        decTotal = decTotal + prices[i]
        decNum += 1

averagePrice.append(janTotal/janNum)
averagePrice.append(febTotal/febNum)
averagePrice.append(marTotal/marNum)
averagePrice.append(aprTotal/aprNum)
averagePrice.append(mayTotal/mayNum)
averagePrice.append(junTotal/junNum)
averagePrice.append(julTotal/julNum)
averagePrice.append(augTotal/augNum)
averagePrice.append(sepTotal/sepNum)
averagePrice.append(octTotal/octNum)
averagePrice.append(novTotal/novNum)
averagePrice.append(decTotal/decNum)

print(min(averagePrice), max(averagePrice))


plt.figure()
plt.ylim(185000, 230000)
plt.title("Average median listing prices nation wide per month")
plt.xlabel("Month")
plt.ylabel("Prices $")
plt.bar(xlab,averagePrice)
